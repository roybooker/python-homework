# %%
# Import csv library
from pathlib import Path
import csv

print(Path.cwd())
# Out:
# C:\Users\USER\bootcamp\python_homework\pybank

# %%
# Set the file path
csvpath = Path('budget_data.csv')

# @TODO: Initialize the metric variables

count_months = 0
total_pnl = 0
average_pnl = 0
minimum_pnl = 0
maximum_pnl = 0

# Initialise list of records of the months
records_months = []

# Initialise Profit/Losses
profit_losses = 0

# Initialize lists to hold profitable and unprofitable day profits/losses

profitable_days = []
unprofitable_days = []

# %%
# Open the csv file as an object
with open(csvpath, 'r') as csvfile:
    
    #Print the datatype of the file object
    print(type(csvfile))
    
    # Pass in the csv file to the csv.reader() function
    csvreader = csv.reader(csvfile, delimiter=',')
    # Print datatype of the csvreader
    print(type(csvreader))
    
    #Go to next row from the start of file
    header = next(csvreader)
    profit_losses += 1
    #Print header
    print(f"{header} <----- HEADER")          
    # Read each row of data after the header
    for row in csvreader: 
        # Print the row
        print(row)
        # Set salary variable equal to the value in the 4th column of each row
        date = int(row[1])
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses'] <----- HEADER
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ...

# %%
# Open the csv file as an object
with open(csvpath, 'r') as csvfile:
    
    #Print the datatype of the file object
    print(type(csvfile))
    
    # Pass in the csv file to the csv.reader() function
    csvreader = csv.reader(csvfile, delimiter=',')
    header = next(csvreader)
    # Print datatype of the csvreader
    print(type(csvreader))
    # Read each row of data after the header
    #Go to next row from the start of file
     
    for row in csvreader:
        # Print the row
        # print(row)
       
        count_months += 1
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>

# %%
print(count_months)
# Out:
# 86

# %%
#The total number of months included in the dataset.
# Iterate over each element of the list
for row in trading_pnl:


       # Cumulatively sum up the total months
    months_year += row(0)
    count +=1
    
    # Cumulatively sum up the total profits/losses and count of trading days
    if minimum == 0:
        minimum = day_pnl
    elif day_pnl < minimum:
        minimum = day_pnl
    elif day_pnl > maximum:
        maximum = day_pnl
        
    # Logic to determine profitable vs. unprofitable days
    if day_pnl > 0:
        profitable_days.append(day_pnl)
    elif day_pnl <= 0:
        unprofitable_days.append(day_pnl)

# %%
#The total number of months included in the dataset.



#The net total amount of Profit/Losses over the entire period.


#The average of the changes in Profit/Losses over the entire period.


#The greatest increase in profits (date and amount) over the entire period.


#The greatest decrease in losses (date and amount) over the entire period.

# %%
#The total number of months included in the dataset.



#The net total amount of Profit/Losses over the entire period.


#The average of the changes in Profit/Losses over the entire period.


#The greatest increase in profits (date and amount) over the entire period.


#The greatest decrease in losses (date and amount) over the entire period.

# %%
print(len(records_months))
# Out:
# 1

# %%
with open(csvpath, 'r') as csvfile:

    line_num = 1
    for line in csvfile:
        print(f"line {line_num}: {line}")
        line_num += 1
# Out:
# line 1: Date,Profit/Losses
#
# line 2: Jan-2010,867884
#
# line 3: Feb-2010,984655
#
# line 4: Mar-2010,322013
#
# line 5: Apr-2010,-69417
#
# line 6: May-2010,310503
#
# line 7: Jun-2010,522857
#
# line 8: Jul-2010,1033096
#
# line 9: Aug-2010,604885
#
# line 10: Sep-2010,-216386
#
# line 11: Oct-2010,477532
#
# line 12: Nov-2010,893810
#
# line 13: Dec-2010,-80353
#
# line 14: Jan-2011,779806
#
# line 15: Feb-2011,-335203
#
# line 16: Mar-2011,697845
#
# line 17: Apr-2011,793163
#
# line 18: May-2011,485070
#
# line 19: Jun-2011,584122
#
# line 20: Jul-2011,62729
#
# line 21: Aug-2011,668179
#
# line 22: Sep-2011,899906
#
# line 23: Oct-2011,834719
#
# line 24: Nov-2011,132003
#
# line 25: Dec-2011,309978
#
# line 26: Jan-2012,-755566
#
# line 27: Feb-2012,1170593
#
# line 28: Mar-2012,252788
#
# line 29: Apr-2012,1151518
#
# line 30: May-2012,817256
#
# line 31: Jun-2012,570757
#
# line 32: Jul-2012,506702
#
# line 33: Aug-2012,-1022534
#
# line 34: Sep-2012,475062
#
# ...
